# %% [markdown]
# # Import Libraries and model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch

# %%
from huggingface_hub import login

# Paste your token inside the string
login(token="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")

# %%
model_id =   "google/gemma-2b-it"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    torch_dtype='auto',
)
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# # Prompt function

# %%
def build_gemma_prompt(concept_text):
    return f"""You are an expert AI tutor and note-taking assistant. Your job is to help users understand machine learning and AI concepts.

[EXAMPLE]

Text: Overfitting is a problem in machine learning where a model performs well on training data but poorly on new data. It happens when the model learns noise or irrelevant patterns instead of the true signal. Overfitting is often caused by having too many parameters or not enough data. It leads to poor generalization. Techniques like regularization or cross-validation are used to reduce overfitting.

Summary:
Overfitting happens when a machine learning model learns the training data too well, including noise. This results in poor performance on new or unseen data. It’s a sign that the model hasn’t generalized well. Overfitting is common with complex models or small datasets. Regularization and cross-validation are techniques used to avoid it.

Key Terms:
1. Overfitting
2. Generalization
3. Noise
4. Regularization
5. Cross-validation

Flashcards:
Q1: What is overfitting in machine learning?
A1: When a model performs well on training data but poorly on new data because it learned noise.

Q2: Why does overfitting happen?
A2: It can occur due to complex models, too many parameters, or not enough data.

Q3: What does overfitting indicate about generalization?
A3: That the model has poor generalization to new data.

Q4: Name two methods to reduce overfitting.
A4: Regularization and cross-validation.

Q5: How is overfitting different from underfitting?
A5: Overfitting learns too much (including noise); underfitting learns too little.

[NEW INPUT]

Text: {concept_text.strip()}

Now follow the same format with a new response.
"""

# %%
concept = """Gradient descent is an optimization algorithm used to minimize a loss function by updating
model parameters in the direction of the negative gradient..."""

prompt = build_gemma_prompt(concept)
output = pipe(prompt, max_new_tokens=700, temperature=0.3, do_sample=True)

print(output[0]["generated_text"].replace(prompt, "").strip())
# Out:
# Sure, here is the response you requested:
#
# **Q1: What is gradient descent in machine learning?**
# A1: Gradient descent is an optimization algorithm used to minimize a loss function by updating model parameters in the direction of the negative gradient.
#
# **Q2: How does gradient descent work?**
# A2: Gradient descent iterates over the training data and updates the model parameters in the direction that minimizes the loss function. The loss function measures how well the model fits the training data.
#
# **Q3: What is the role of the loss function in gradient descent?**
# A3: The loss function measures how well the model fits the training data. It is used to guide the optimization algorithm towards a model that minimizes the loss function.
#
# **Q4: What are the advantages and disadvantages of gradient descent?**
# A4: Advantages of gradient descent include its ability to converge to a global minimum and its robustness to small changes in the training data. Disadvantages include its slow convergence speed and the possibility of getting stuck in local minima.
#
# **Q5: How is gradient descent different from other optimization algorithms?**
# A5: Gradient descent is an iterative algorithm that updates model parameters in the direction of the negative gradient. Other optimization algorithms, such as stochastic gradient descent, do not have this iterative structure.

# %% [markdown]
# # Modifying the prompt function

# %%
def build_gemma_prompt(concept_text):
    return f"""You are an expert AI tutor and note-taking assistant. Your job is to help users understand machine learning and AI concepts.

[EXAMPLE]

Text: Overfitting is a problem in machine learning where a model performs well on training data but poorly on new data. It happens when the model learns noise or irrelevant patterns instead of the true signal. Overfitting is often caused by having too many parameters or not enough data. It leads to poor generalization. Techniques like regularization or cross-validation are used to reduce overfitting.

Summary:
Overfitting happens when a machine learning model learns the training data too well, including noise. This results in poor performance on new or unseen data. It’s a sign that the model hasn’t generalized well. Overfitting is common with complex models or small datasets. Regularization and cross-validation are techniques used to avoid it.

Key Terms:
1. Overfitting
2. Generalization
3. Noise
4. Regularization
5. Cross-validation

Flashcards:
Q1: What is overfitting in machine learning?
A1: When a model performs well on training data but poorly on new data because it learned noise.

Q2: Why does overfitting happen?
A2: It can occur due to complex models, too many parameters, or not enough data.

Q3: What does overfitting indicate about generalization?
A3: That the model has poor generalization to new data.

Q4: Name two methods to reduce overfitting.
A4: Regularization and cross-validation.

Q5: How is overfitting different from underfitting?
A5: Overfitting learns too much (including noise); underfitting learns too little.

[NEW INPUT]

Text: {concept_text.strip()}

Now follow the same format and return:
1. A 5-sentence summary
2. 5 key terms
3. 5 flashcards

"""

# %%
concept = """Gradient descent is an optimization algorithm used to minimize a loss function
by updating model parameters in the direction of the negative gradient. The learning rate controls the step size.
It is widely used in training machine learning models like linear regression and neural networks.
Variants include stochastic and mini-batch gradient descent. Proper tuning of the learning rate is critical to convergence."""

prompt = build_gemma_prompt(concept)
output = pipe(prompt, max_new_tokens=1500, temperature=0.3, do_sample=True)

print(output[0]["generated_text"].replace(prompt, "").strip())
# Out:
# **1. Summary**
# Gradient descent is an optimization algorithm used to minimize a loss function by updating model parameters in the direction of the negative gradient. It is widely used in training machine learning models.
#
# **2. Key Terms**
# 1. Gradient descent
# 2. Loss function
# 3. Learning rate
# 4. Mini-batch gradient descent
# 5. Stochastic gradient descent
#
# **3. Flashcards**
# Q1: What is the purpose of the learning rate in gradient descent?
# A1: It controls the step size of the update.
#
# Q2: What is the difference between stochastic and mini-batch gradient descent?
# A2: Stochastic gradient descent updates the model parameters for each data point, while mini-batch gradient descent updates the parameters for a small subset of data points.
#
# Q3: What is the role of the loss function in gradient descent?
# A3: It measures the difference between the predicted and actual values.
#
# Q4: What is the purpose of tuning the learning rate in gradient descent?
# A4: It ensures that the model converges to a minimum loss value.
#
# Q5: What is the difference between overfitting and underfitting?
# A5: Overfitting learns too much (including noise), while underfitting learns too little.

# %%
concept = """The transformer architecture is a deep learning model designed for sequence data. \
 It relies on self-attention mechanisms instead of recurrence, enabling parallel processing.\
 Transformers excel in tasks like language modeling, translation, and summarization. \
 The architecture includes encoder and decoder blocks. Popular models like BERT, GPT, and T5 are based on transformers.
"""

prompt = build_gemma_prompt(concept)
output = pipe(prompt, max_new_tokens=1500, temperature=0.3, do_sample=True)

print(output[0]["generated_text"].replace(prompt, "").strip())
# Out:
# **1. Summary**
# The transformer architecture is a deep learning model for sequence data that uses self-attention mechanisms instead of recurrent connections. It excels in tasks like language modeling, translation, and summarization.
#
# **2. Key Terms**
# 1. Self-attention
# 2. Transformer
# 3. Encoder
# 4. Decoder
# 5. Sequence data
#
# **3. Flashcards**
# Q1: What is self-attention in the transformer architecture?
# A1: Self-attention allows the model to focus on different parts of the input sequence simultaneously.
#
# Q2: What is the role of the encoder and decoder in the transformer architecture?
# A2: The encoder processes the input sequence and generates a representation, while the decoder uses this representation for language modeling.
#
# Q3: What is the difference between the encoder and decoder in the transformer architecture?
# A3: The encoder takes the entire input sequence, while the decoder takes a contextualized representation from the encoder.
#
# Q4: Which popular model is based on the transformer architecture?
# A4: BERT, GPT, and T5 are all based on the transformer architecture.
#
# Q5: How does the transformer architecture handle sequence data?
# A5: The self-attention mechanism allows the model to focus on different parts of the sequence simultaneously, enabling parallel processing.

# %%
concept = """Few-shot learning allows models to generalize from only a few labeled examples, while zero-shot learning enables inference without any task-specific examples. \
These capabilities are often achieved using large language models.\
 Prompt engineering plays a key role in this process.\
  It’s useful for scenarios where labeled data is scarce or unavailable.\
   GPT-style models have demonstrated strong few-shot and zero-shot performance.
"""

prompt = build_gemma_prompt(concept)
output = pipe(prompt, max_new_tokens=1500, temperature=0.3, do_sample=True)

print(output[0]["generated_text"].replace(prompt, "").strip())
# Out:
# **1. Summary:**
# Few-shot learning allows models to generalize from only a few labeled examples, while zero-shot learning enables inference without any task-specific examples. These capabilities are often achieved using large language models.
#
# **2. Key Terms:**
# - Few-shot learning
# - Zero-shot learning
# - Prompt engineering
#
# **3. Flashcards:**
# Q1: What is the difference between few-shot learning and zero-shot learning?
# A1: Few-shot learning requires labeled data, while zero-shot learning does not require any labeled data.
#
# Q2: What is the role of prompt engineering in few-shot learning?
# A2: Prompt engineering is crucial in few-shot learning by guiding the model towards the desired output.
#
# Q3: What is the purpose of prompt engineering in zero-shot learning?
# A3: The purpose of prompt engineering in zero-shot learning is to prepare the model for the task at hand.
#
# Q4: How does prompt engineering impact the model's performance?
# A4: Prompt engineering can significantly impact the model's performance by guiding it towards the desired output.
#
# Q5: How does prompt engineering differ from other techniques in natural language processing?
# A5: Prompt engineering focuses on guiding the model's behavior during training, whereas other techniques like transfer learning and pre-training focus on transferring knowledge from other sources.

# %%
concept = """RAG combines retrieval and generation by using an external knowledge base to supplement the model's answers. \
A retriever finds relevant documents, and a generator uses them to create a response.\
 It helps reduce hallucination and provides more grounded answers.\
  RAG is commonly used in question-answering and chatbots. \
  It integrates search with language generation.
"""

prompt = build_gemma_prompt(concept)
output = pipe(prompt, max_new_tokens=1500, temperature=0.3, do_sample=True)

print(output[0]["generated_text"].replace(prompt, "").strip())
# Out:
# **1. Summary**
# RAG combines retrieval and generation by using an external knowledge base to enhance the model's responses. It addresses hallucination and provides more grounded answers.
#
# **2. Key Terms**
# 1. Retrieval
# 2. Generation
# 3. Knowledge base
# 4. Hallucination
# 5. Grounded answers
#
# **3. Flashcards**
# Q1: What is the purpose of the knowledge base in RAG?
# A1: It provides relevant documents for retrieval and generation.
#
# Q2: What is the role of the retriever and generator in RAG?
# A2: The retriever finds relevant documents, and the generator uses them to create a response.
#
# Q3: How does the knowledge base help reduce hallucination?
# A3: It provides a structured representation of the information, reducing the model's ability to generate irrelevant or illogical responses.
#
# Q4: What is the main advantage of using a knowledge base in RAG?
# A4: It improves the model's accuracy by providing more relevant and grounded responses.
#
# Q5: How does RAG integrate search with language generation?
# A5: It allows users to search for relevant information and then generate a response based on the retrieved documents.

# %%
concept = """Fine-tuning is the process of continuing training a pretrained language model on a domain-specific dataset.\
 It adapts the model to new tasks or improves performance in a specific context. \
 Techniques include full fine-tuning, LoRA, and PEFT.\
  Fine-tuning requires careful data preparation and tuning of hyperparameters. \
  It’s commonly used to build custom AI assistants or specialized models.
  """


prompt = build_gemma_prompt(concept)
output = pipe(prompt, max_new_tokens=1500, temperature=0.3, do_sample=True)

print(output[0]["generated_text"].replace(prompt, "").strip())
# Out:
# **Summary:**
# Fine-tuning is the process of adapting a pre-trained language model to a new domain. It allows the model to learn specific tasks or improve performance in a particular context.
#
# **Key Terms:**
# 1. Fine-tuning
# 2. Domain-specific
# 3. Pre-trained
# 4. Hyperparameters
# 5. Custom AI assistants
#
# **Flashcards:**
# Q1: What is fine-tuning in language model training?
# A1: The process of continuing training a pre-trained language model on a domain-specific dataset.
#
# Q2: What are the different types of fine-tuning?
# A2: Full fine-tuning, LoRA, and PEFT.
#
# Q3: What is the purpose of fine-tuning?
# A3: To adapt the model to new tasks or improve performance in a specific context.
#
# Q4: What are the key steps involved in fine-tuning?
# A4: Data preparation, hyperparameter tuning, and model training.
#
# Q5: How does fine-tuning differ from pre-training?
# A5: Fine-tuning involves training on a specific domain, while pre-training is done on a general dataset.

# %% [markdown]
# # Loading the app

# %%
def get_completion_from_ai(prompt):
    outputs = pipe(prompt, max_length=512, do_sample=True, temperature=0.7)
    return outputs[0]["generated_text"].replace(prompt," ").strip()

# %%
def tutor_chat(user_input):
    prompt = build_gemma_prompt(user_input)
    response = get_completion_from_ai(prompt)
    return response

# %%
import gradio as gr

# %%
with gr.Blocks() as demo:
    gr.Markdown("# 🤖 AI Tutor Chatbot")
    user_input = gr.Textbox(label="Enter you article")
    output = gr.Textbox(label="AI Tutor's Response", lines=20)
    user_input.submit(tutor_chat, inputs=user_input, outputs=output)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://54ad362130760d189d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://54ad362130760d189d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
